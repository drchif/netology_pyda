# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
url='http://yustiks.ru/housing.csv'
s=requests.get(url).content
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(io.StringIO(s.decode('utf-8')),  delim_whitespace=True, names=names)
data.head()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ...

# %%
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv('housing.csv',  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
CRIM = data['CRIM']
ZN = data['ZN']
INDUS = data['INDUS']
CHAS = data['CHAS']
NOX = data['NOX']
RM = data['RM']
AGE = data['AGE']
DIS = data['DIS']
RAD = data['RAD']
TAX = data['TAX']
PTRATIO = data['PTRATIO']
B = data['B']
LSTAT = data['LSTAT']
MEDV = data['MEDV']

# %%
sns.distplot(CRIM,10)
plt.title('CRIM')
plt.show()
#Exponention OR Geometric

# %%
sns.distplot(ZN)
plt.title('ZN')
plt.show()
#GEOMETRIC

# %%
sns.distplot(INDUS)
plt.title('INDUS')
plt.show()
#??GEOMETRIC +NEGAtIV binominal

# %%
sns.distplot(CHAS)
plt.title('CHAS')
plt.show()
#BERNOULLI

# %%
sns.distplot(NOX,30)
plt.title('NOX')
plt.show()
#Binomial

# %%
sns.distplot(RM,30)
plt.title('RM')
plt.show()
#NORMAL

# %%
sns.distplot(AGE,30)
plt.title('AGE')
plt.show()
#GEOMETRIC развернутый?

# %%
sns.distplot(DIS,30)
plt.title('DIS')
plt.show()
#Log Normal

# %%
sns.distplot(RAD,30)
plt.title('RAD')
plt.show()
#???

# %%
sns.distplot(TAX)
plt.title('TAX')
plt.show()
#???

# %%
sns.distplot(PTRATIO)
plt.title('PTRATIO')
plt.show()

# %%
sns.distplot(B,20)
plt.title('B')
plt.show()
#Geometric

# %%
sns.distplot(LSTAT,20)
plt.title('LSTAT')
plt.show()
#Chi-Squared

# %%
sns.distplot(MEDV,100)
plt.title('MEDV')
plt.show()
#Poison?

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %%
plt.plot(MEDV, LSTAT, 'r.')
plt.xlabel('MEDV')
plt.ylabel('LSTAT')
plt.title('Линейная регрессия')

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
MEDV = np.array(MEDV).reshape(-1,1)#Преобразуем в список
LSTAT = np.array(LSTAT).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    MEDV,
    LSTAT,
    test_size = 0.2,
    random_state = 3 #Начало генерации случайно последовательности с указаной позиции
)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predicted_y = model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.56636808418299478

# %%
plt.xlabel('MEDV')
plt.ylabel('LSTAT')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(-50, 200, 100)
# Посчитаем предсказанные значения
y = model.coef_*x + model.intercept_
y = np.transpose(y)#транспонирование значений - переворот
plt.plot(x,y)
plt.plot(MEDV, LSTAT, 'r.')
plt.xlim(0,55)
plt.ylim(-2,40)
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop). Написать код.

# %%
data.info()
# в зависимости от поля. В поле страна нет пустых значений.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
# Country (region)           156 non-null object
# Ladder                     156 non-null int64
# SD of Ladder               156 non-null int64
# Positive affect            155 non-null float64
# Negative affect            155 non-null float64
# Social support             155 non-null float64
# Freedom                    155 non-null float64
# Corruption                 148 non-null float64
# Generosity                 155 non-null float64
# Log of GDP
# per capita      152 non-null float64
# Healthy life
# expectancy    150 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %%
data.groupby('Country (region)').count()
#156 стран
# Out:
#                           Ladder  SD of Ladder  Positive affect  \
# Country (region)
# Afghanistan                    1             1                1
# Albania                        1             1                1
# Algeria                        1             1                1
# Argentina                      1             1                1
# Armenia                        1             1                1
# Australia                      1             1                1
# Austria                        1             1                1
# Azerbaijan                     1             1                1
# Bahrain                        1             1                1
# Bangladesh                     1             1                1
# Belarus                        1             1                1
# Belgium                        1             1                1
# Benin                          1             1                1
# ...

# %% [markdown]
# Добавить новую колонку в таблицу - 'continent'. Каждая страна относится к определенному материку. Всего материко 6:
# *   Евразия,
# *   Африка,
# *   Северная Америка,
# *   Южная Америка,
# *   Австралия,
# *   Антарктида.
#
# Таким образом, мы можем классифицировать каждый элемент как член определенного класса - континента.

# %%
conti = pd.read_csv('country-and-continent-codes-list-csv_csv.txt')
conti['Country'] = conti.Country_Name.str.split(',',expand = True)[0]

conti.head()
# Out:
#   Continent_Name Continent_Code                                  Country_Name  \
# 0           Asia             AS              Afghanistan, Islamic Republic of
# 1         Europe             EU                          Albania, Republic of
# 2     Antarctica             AN  Antarctica (the territory South of 60 deg S)
# 3         Africa             AF      Algeria, People's Democratic Republic of
# 4        Oceania             OC                                American Samoa
#
#   Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number  \
# 0                      AF                       AFG             4.0
# 1                      AL                       ALB             8.0
# 2                      AQ                       ATA            10.0
# 3                      DZ                       DZA            12.0
# 4                      AS                       ASM            16.0
#
#                                         Country
# ...

# %%
data_2 = data.merge(conti, left_on='Country (region)', right_on='Country')
data_2.describe()
# Out:
#            Ladder  SD of Ladder  Positive affect  Negative affect  \
# count  146.000000    146.000000       145.000000       145.000000
# mean    78.945205     77.520548        78.275862        77.413793
# std     45.439734     45.238558        45.440205        44.671422
# min      1.000000      1.000000         1.000000         1.000000
# 25%     40.250000     38.500000        39.000000        38.000000
# 50%     79.500000     78.000000        78.000000        77.000000
# 75%    118.750000    116.750000       118.000000       116.000000
# max    156.000000    156.000000       154.000000       154.000000
#
#        Social support     Freedom  Corruption  Generosity  \
# count      145.000000  145.000000  138.000000  145.000000
# mean        78.041379   77.434483   73.152174   80.172414
# std         45.110339   44.885628   42.042020   44.973348
# min          1.000000    1.000000    1.000000    1.000000
# 25%         39.000000   39.000000   37.500000   44.000000
# ...

# %% [markdown]
# Нарисовать sns.pairplot для класса - континет. Из графика сделать вывод о том, какие континеты похожи.

# %%
# пример кода на точечный график по континентам
sns.set(style="ticks", color_codes=True)
fig = sns.pairplot(data=data_2, hue='Continent_Name')
#fig = sns.pairplot(data=data, hue='continent')
plt.show()

# %%
#Северная и Южная Америка

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
sns.heatmap(data_2.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %%
#Чем больше ВВП на душу тем здоровее нация
#Позитив связан со свободой
#и т.д.

# %% [markdown]
# **Регрессионный анализ** - можно ли провести линейную зависимость между двумя выборками. Возьмем Ladder - удовлетворение жизнью, и generosity - доброта. Мы хотим найти прямую, которая разделит точки в пространстве наполовину. Это можно сделать графически. Нарисовать график. Можно ли сказать, что данная прямая является собственным вектором? Сделать график регрессионной прямой на данных и собственных векторов.

# %%
ladder = data[data['Country (region)']!='Qatar'].Ladder
ladder.count()
# Out:
# 155

# %%
generosity = data[data['Country (region)']!='Qatar'].Generosity
generosity.count()
# Out:
# 155

# %%
import numpy.linalg as la
import math
from sklearn.preprocessing import StandardScaler

Y = np.vstack((ladder, generosity)).T #считаем матрицу ковариаций
w,v = la.eig(np.cov(Y.T))#считаем собственные значения и собственный вектор

for i in range(len(w)):
    fig = plt.gcf()
    fig.set_size_inches(6,6)
    plt.suptitle('Собственный вектор № '+ str(i+1), fontsize=16)    
    plt.plot(ladder, generosity, 'g.', zorder=1)
    print('Собственное значение: ', round(w[i],2), 'Собственный вектор: ', v[:,i])
    plt.xlabel('ladder')
    #plt.xlim(0,7)#пределы Икса
    plt.ylabel('generosity')
    #plt.ylim(-2,5)
    plt.plot([ladder.mean(), ladder.mean() + math.sqrt(w[i]) * v[:,i][0]], #Среднее\Среднее+корень квадратный собственного значения умножение на собственный вектор
    #Суть показывает основной разброс (нахождение) данных
             [generosity.mean(), generosity.mean() + math.sqrt(w[i]) * v[:,i][1]],color='red', linewidth=3)
    
    plt.show()
# Out:
# Собственное значение:  3035.63 Собственный вектор:  [ 0.71116669  0.70302343]
# Собственное значение:  1017.6 Собственный вектор:  [-0.70302343  0.71116669]

# %%
sns.regplot(x='Ladder',y = 'Generosity', data = data)

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
data_bern = stats.bernoulli.rvs(size=10,p=1/6)
ax= sns.distplot(data_bern,
                 kde=False,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Бернулли', ylabel='Вероятность')
plt.title('Плотность рапределения подбрасывания кубика')
plt.show()

# %% [markdown]
# моделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
n_experiments = 1000
n_bernoulli_trials = 100

rng = np.random.RandomState(100)
outcomes = np.empty(n_experiments, dtype=np.float)

for i in range(n_experiments):
    cube_flips = rng.randint(0, 6, size=n_bernoulli_trials)
    # cube_flips - выборка из 100 подбрасываний
    head_counts = np.sum(cube_flips)
    outcomes[i] = head_counts

print('Подбрасывание кубика: ', cube_flips)
plt.hist(outcomes)
plt.xlabel('Количество выпадений значения куба в 1000')
plt.ylabel('Количество встречаемости значения')
plt.show()
# Out:
# Подбрасывание кубика:  [2 4 4 2 0 3 5 5 5 1 3 3 3 5 2 4 1 5 5 4 3 4 3 2 1 5 4 5 5 3 5 3 1 1 0 1 1
#  3 5 2 2 2 3 3 1 5 3 3 1 5 0 0 4 5 5 0 5 2 4 3 5 5 2 1 2 0 2 3 4 2 5 1 3 3
#  3 3 0 0 1 3 2 4 5 0 3 2 4 1 0 2 2 2 5 2 3 4 3 0 1 0]

# %%
#график изменил из-за теории больших цисел. Лубое распределени можно привести к нормальному
