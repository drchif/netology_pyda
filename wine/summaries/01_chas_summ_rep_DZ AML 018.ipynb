# %% [markdown]
# ## Цель
# Предсказать качество вина на основании его физических свойств.

# %% [markdown]
# График 1 - Вина по типу и качеству

# %%
# Wine type and Wine quality data count
fig, ax = plt.subplots(1,2,figsize=(15,6))

# Wine type
sns.countplot(df["type"], ax=ax[0])
ax[0].set_title("Wine type")

# Wine quality
sns.countplot(df["quality"], ax=ax[1])
ax[1].set_title("Wine type")
# Out:
# Text(0.5, 1.0, 'Wine type')

# %% [markdown]
# Таблица 1 - средние физические свойства вин по типу.

# %%
df.groupby('type')['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol'].mean()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# type
# red         8.326365          0.527659     0.271551        2.538512
# white       6.855123          0.278071     0.334199        6.394343
#
#        chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# type
# red     0.087497            15.841808             46.463905  0.996752
# white   0.045771            35.317146            138.340144  0.994026
#
#              pH  sulphates    alcohol
# type
# red    3.310590   0.657866  10.419617
# white  3.188154   0.489700  10.516772

# %% [markdown]
#  На основании проведенного иследования было принято решение сгруппировать качество на 2 класса
#  - Класс 1 - качество до 6 включительно
#  - Класс 2 - качество от 6

# %% [markdown]
# Было использовано 2 модели предсказания
#  - Logistic Regression Result
#  - Decision tree
# # Которые дали результаты (accuracy) 0.814 и 0.825 соответсвенно

# %% [markdown]
# В результате иследования выявленно существенное отличие качества вина от его типа (Приложение 1).

# %% [markdown]
# ## Предложение: Улучшить модель предсказания за счет построение отдельных моделей в зависимости от типа вина.

# %% [markdown]
#  ## Приложение 1 - распределение физических характеристик вин в зависимости от типа

# %%
# Each wine type, plotting check of whole data, sample=1000.
sns.pairplot(df.sample(n=1000, random_state=10), hue="type", hue_order=['white', 'red'])
plt.legend()
